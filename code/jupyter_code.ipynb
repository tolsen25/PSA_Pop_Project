# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
from plotnine import ggplot, aes, geom_histogram,labs
import seaborn as sns

import time
testPkl = pd.read_pickle("last2years.pkl")

from plotnine import ggplot, aes, geom_histogram,labs
testPkl = testPkl[testPkl["Total"] > 400]
testPkl.head
# Out:
# <bound method NDFrame.head of                                        Set Name  Year Auth PR1 FR1.5 GOOD2  \
# 104                                      Bowman  2022   12   0     –     0
# 105                          Bowman 1st Edition  2022   15   0     –     0
# 109                               Bowman Chrome  2022   22   0     –     1
# 113                Bowman Chrome Bowman in 3-D!  2022    8   1     –     0
# 118                 Bowman Chrome Hi-FI Futures  2022    6   0     –     0
# ...                                         ...   ...  ...  ..   ...   ...
# 6682                         Topps Stars of MLB  2023    2   0     –     0
# 6683              Topps Stars of the MLB Chrome  2023    1   0     –     0
# 6714                   Topps Throwback Thursday  2023    0   1     –     0
# 6728            Topps Tribute Tribute Autograph  2023    6   0     –     0
# 6749  Topps World Baseball Classic GlobAL Stars  2023    0   0     –     0
#
#      VG3 VG‑EX4 EX5 EX‑MT6  NM7 NM‑MT8  MINT9 GEM‑MT10  Total
# 104    0      0   6     28   55    330  1,777    1,772   3980
# 105    0      0   2     19   31    160  1,631    6,118   7976
# 109    4     13  34    131  105    782  4,450    4,172   9714
# 113    0      0   1      0   10     43    345      359    767
# 118    0      2   1      4    7     61    448      205    734
# ...   ..    ...  ..    ...  ...    ...    ...      ...    ...
# 6682   0      1   3     10   15     77    471    1,895   2474
# 6683   0      0   5      7    4     22    169      684    892
# 6714   0      0   0      2    5     21    262      830   1121
# 6728   0      0   0      8   16    122    321       58    531
# 6749   0      0   0      1    4     10     82      386    483
#
# [779 rows x 15 columns]>

# %%
plot = (ggplot(testPkl, aes(x='Total')) +
        geom_histogram(binwidth=5, fill='skyblue', color='black', alpha=0.7) +
        labs(
          
          title = "Title"
          
        ))

# %%
print(plot)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 print(plot)
#
# File ~\anaconda3\Lib\site-packages\plotnine\ggplot.py:105, in ggplot.__str__(self)
#     101 def __str__(self) -> str:
#     102     """
#     103     Print/show the plot
#     104     """
# --> 105     self.draw(show=True)
#     107     # Return and empty string so that print(p) is "pretty"
#     108     return ""
#
# File ~\anaconda3\Lib\site-packages\plotnine\ggplot.py:224, in ggplot.draw(self, show)
#     222 self = deepcopy(self)
#     223 with plot_context(self, show=show):
# --> 224     self._build()
#     226     # setup
#     227     figure, axs = self._create_figure()
#
# File ~\anaconda3\Lib\site-packages\plotnine\ggplot.py:336, in ggplot._build(self)
#     333 layers.setup_data()
#     335 # Apply position adjustments
# --> 336 layers.compute_position(layout)
#     338 # Reset position scales, then re-train and map.  This
#     339 # ensures that facets have control over the range of
#     340 # a plot.
#     341 layout.reset_position_scales()
#
# File ~\anaconda3\Lib\site-packages\plotnine\layer.py:479, in Layers.compute_position(self, layout)
#     477 def compute_position(self, layout: Layout):
#     478     for l in self:
# --> 479         l.compute_position(layout)
#
# File ~\anaconda3\Lib\site-packages\plotnine\layer.py:345, in layer.compute_position(self, layout)
#     343 params = self.position.setup_params(self.data)
#     344 data = self.position.setup_data(self.data, params)
# --> 345 data = self.position.compute_layer(data, params, layout)
#     346 self.data = data
#
# File ~\anaconda3\Lib\site-packages\plotnine\positions\position.py:79, in position.compute_layer(cls, data, params, layout)
#      76     scales = layout.get_scales(pdata["PANEL"].iat[0])
#      77     return cls.compute_panel(pdata, scales, params)
# ---> 79 return groupby_apply(data, "PANEL", fn)
#
# File ~\anaconda3\Lib\site-packages\plotnine\utils.py:596, in groupby_apply(df, cols, func, *args, **kwargs)
#     592 lst = []
#     593 for _, d in df.groupby(cols, observed=True):
#     594     # function fn should be free to modify dataframe d, therefore
#     595     # do not mark d as a slice of df i.e no SettingWithCopyWarning
# --> 596     lst.append(func(d, *args, **kwargs))
#     597 return pd.concat(lst, axis=axis, ignore_index=True)
#
# File ~\anaconda3\Lib\site-packages\plotnine\positions\position.py:77, in position.compute_layer.<locals>.fn(pdata)
#      75     return pdata
#      76 scales = layout.get_scales(pdata["PANEL"].iat[0])
# ---> 77 return cls.compute_panel(pdata, scales, params)
#
# File ~\anaconda3\Lib\site-packages\plotnine\positions\position_stack.py:115, in position_stack.compute_panel(cls, data, scales, params)
#     112     neg = cls.collide(neg, params=params)
#     114 if len(pos):
# --> 115     pos = cls.collide(pos, params=params)
#     117 data = pd.concat([neg, pos], axis=0, ignore_index=True, sort=True)
#     119 if nl_trans:
#
# File ~\anaconda3\Lib\site-packages\plotnine\positions\position.py:232, in position.collide(cls, data, params)
#     229     warn(msg.format(cls.__name__), PlotnineWarning)
#     231 if "ymax" in data:
# --> 232     data = groupby_apply(data, "xmin", cls.strategy, params)
#     233 elif "y" in data:
#     234     data["ymax"] = data["y"]
#
# File ~\anaconda3\Lib\site-packages\plotnine\utils.py:596, in groupby_apply(df, cols, func, *args, **kwargs)
#     592 lst = []
#     593 for _, d in df.groupby(cols, observed=True):
#     594     # function fn should be free to modify dataframe d, therefore
#     595     # do not mark d as a slice of df i.e no SettingWithCopyWarning
# --> 596     lst.append(func(d, *args, **kwargs))
#     597 return pd.concat(lst, axis=axis, ignore_index=True)
#
# File ~\anaconda3\Lib\site-packages\plotnine\positions\position_stack.py:140, in position_stack.strategy(data, params)
#     137 if params["fill"]:
#     138     heights = heights / np.abs(heights[-1])
# --> 140 data["ymin"] = np.min([heights[:-1], heights[1:]], axis=0)
#     141 data["ymax"] = np.max([heights[:-1], heights[1:]], axis=0)
#     142 # less intuitive than (ymin + vjust(ymax-ymin)), but
#     143 # this way avoids subtracting numbers of potentially
#     144 # similar precision
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4094, in DataFrame.__setitem__(self, key, value)
#    4091     self._setitem_array([key], value)
#    4092 else:
#    4093     # set column
# -> 4094     self._set_item(key, value)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4317, in DataFrame._set_item(self, key, value)
#    4314             value = np.tile(value, (len(existing_piece.columns), 1)).T
#    4315             refs = None
# -> 4317 self._set_item_mgr(key, value, refs)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4269, in DataFrame._set_item_mgr(self, key, value, refs)
#    4267     self._mgr.insert(len(self._info_axis), key, value, refs)
#    4268 else:
# -> 4269     self._iset_item_mgr(loc, value, refs=refs)
#    4271 # check if we are modifying a copy
#    4272 # try to set first as we want an invalid
#    4273 # value exception to occur first
#    4274 if len(self):
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4257, in DataFrame._iset_item_mgr(self, loc, value, inplace, refs)
#    4249 def _iset_item_mgr(
#    4250     self,
#    4251     loc: int | slice | np.ndarray,
#    (...)
#    4255 ) -> None:
#    4256     # when called from _set_item_mgr loc can be anything returned from get_loc
# -> 4257     self._mgr.iset(loc, value, inplace=inplace, refs=refs)
#    4258     self._clear_item_cache()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:1139, in BlockManager.iset(self, loc, value, inplace, refs)
#    1136             continue
#    1137         else:
#    1138             # Defer setting the new values to enable consolidation
# -> 1139             self._iset_split_block(blkno_l, blk_locs, refs=refs)
#    1141 if len(removed_blknos):
#    1142     # Remove blocks & update blknos accordingly
#    1143     is_deleted = np.zeros(self.nblocks, dtype=np.bool_)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:1222, in BlockManager._iset_split_block(self, blkno_l, blk_locs, value, refs)
#    1219 if self._blklocs is None:
#    1220     self._rebuild_blknos_and_blklocs()
# -> 1222 nbs_tup = tuple(blk.delete(blk_locs))
#    1223 if value is not None:
#    1224     locs = blk.mgr_locs.as_array[blk_locs]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\blocks.py:1674, in Block.delete(self, loc)
#    1669         nb = type(self)(
#    1670             values, placement=BlockPlacement(locs), ndim=self.ndim, refs=refs
#    1671         )
#    1672         new_blocks.append(nb)
# -> 1674     previous_loc = idx
#    1676 return new_blocks
#
# KeyboardInterrupt:

# %%
sns.histplot(testPkl, x = "Total")
# Out:
# C:\Users\gored\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
# C:\Users\gored\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
# <Axes: xlabel='Total', ylabel='Count'>
